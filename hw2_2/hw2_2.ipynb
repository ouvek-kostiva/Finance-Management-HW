# %%
import sqlite3,pandas
import os

### Create Table foodt If Not Exists -- START ###
#Connecting to DB
location = "hw2.db"
conn = sqlite3.connect(location)
c = conn.cursor()

table_name = "foodt"
new_field = "company"
field_type = "TEXT"

# Creating a new SQLite table with 1 column
c.execute('CREATE TABLE IF NOT EXISTS {tn} ({nf} {ft})'\
        .format(tn=table_name1, nf=new_field, ft=field_type))
conn.commit()
#

new_column1 = "date" 
column_type = "TEXT"

#Create new column
c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ct}"\
        .format(tn=table_name, cn=new_column1, ct=column_type))
conn.commit()
#

new_column2 = "per" 
column_type2 = "REAL"

#Create new column
c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ct}"\
        .format(tn=table_name, cn=new_column2, ct=column_type2))
conn.commit()
#

conn.close()
### Create Table foodt If Not Exists -- START ###

import pandas

csvfile = "food.csv"

block = pandas.read_csv(csvfile,sep=',',chunksize=24,iterator=True)
for i in block:
    blockdf.append = list(block)[i]
print

# %%
import pandas

csvfile = "food.csv"

block = pandas.read_csv(csvfile,sep=',',chunksize=24,iterator=True)

blockdf = pandas.DataFrame(index=index, columns=columns)
for i in block:
    blockdf = blockdf.append(list(block)[i])
print(blockdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-ed8e3c28e287> in <module>()
#       5 block = pandas.read_csv(csvfile,sep=',',chunksize=24,iterator=True)
#       6
# ----> 7 blockdf = pandas.DataFrame(index=index, columns=columns)
#       8 for i in block:
#       9     blockdf = blockdf.append(list(block)[i])
#
# NameError: name 'index' is not defined

# %%
import sqlite3,pandas
import os

# Read CSV file by date block
import pandas


csvfile = "food.csv"

block = pandas.read_csv(csvfile,sep=',',chunksize=24,iterator=True)
df = list(block)[0]
print(df['證券代碼'][0])
print(df['年月日'][0])
print(df['本益比-TSE'][0])
df.columns = ['name', 'date', 'per']
print(df)
# Out:
# 1201 味全
# 2017/03/31
# 0.0
#              name        date    per
# 0         1201 味全  2017/03/31   0.00
# 1         1203 味王  2017/03/31  22.81
# 2         1210 大成  2017/03/31   9.57
# 3         1213 大飲  2017/03/31  66.30
# 4         1215 卜蜂  2017/03/31  11.51
# 5         1216 統一  2017/03/31  22.23
# 6        1217 愛之味  2017/03/31  35.90
# 7         1218 泰山  2017/03/31  15.85
# 8         1219 福壽  2017/03/31  33.88
# 9         1220 台榮  2017/03/31  11.99
# 10       1225 福懋油  2017/03/31  14.84
# 11        1227 佳格  2017/03/31  26.36
# 12        1229 聯華  2017/03/31  10.74
# 13       1231 聯華食  2017/03/31  11.32
# 14       1232 大統益  2017/03/31  16.34
# 15        1233 天仁  2017/03/31  20.03
# 16        1234 黑松  2017/03/31  12.24
# 17        1235 興泰  2017/03/31   7.24
# 18        1236 宏亞  2017/03/31  26.30
# 19   1256 鮮活果汁-KY  2017/03/31  17.72
# 20        1702 南僑  2017/03/31  12.51
# 21        1737 臺鹽  2017/03/31  17.24
# 22  910322 康師傅-DR  2017/03/31   0.00
# ...

# %%
import sqlite3,pandas
import os


#Connecting to DB
conn = sqlite3.connect(location)
c = conn.cursor()

table_name1 = "foodt"
new_field = "company"
field_type = "TEXT"

# Creating a new SQLite table with 1 column
c.execute('CREATE TABLE {tn} ({nf} {ft})'\
        .format(tn=table_name1, nf=new_field, ft=field_type))
conn.commit()
conn.close()
#

new_column1 = "date" 
column_type = "TEXT"

#Create new column
c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ct}"\
        .format(tn=table_name, cn=new_column1, ct=column_type))
conn.commit()
conn.close()
#

new_column2 = "per" 
column_type2 = "REAL"

#Create new column
c.execute("ALTER TABLE {tn} ADD COLUMN '{cn}' {ct}"\
        .format(tn=table_name, cn=new_column2, ct=column_type2))
conn.commit()
conn.close()
#

# %%
import pandas

csvfile = "food.csv"
print(pandas.read_csv(csvfile,skiprows=0,nrows=24))
print()
print(pandas.read_csv(csvfile,skiprows=24,nrows=24))
# Out:
#              證券代碼         年月日  本益比-TSE
# 0         1201 味全  2017/03/31     0.00
# 1         1203 味王  2017/03/31    22.81
# 2         1210 大成  2017/03/31     9.57
# 3         1213 大飲  2017/03/31    66.30
# 4         1215 卜蜂  2017/03/31    11.51
# 5         1216 統一  2017/03/31    22.23
# 6        1217 愛之味  2017/03/31    35.90
# 7         1218 泰山  2017/03/31    15.85
# 8         1219 福壽  2017/03/31    33.88
# 9         1220 台榮  2017/03/31    11.99
# 10       1225 福懋油  2017/03/31    14.84
# 11        1227 佳格  2017/03/31    26.36
# 12        1229 聯華  2017/03/31    10.74
# 13       1231 聯華食  2017/03/31    11.32
# 14       1232 大統益  2017/03/31    16.34
# 15        1233 天仁  2017/03/31    20.03
# 16        1234 黑松  2017/03/31    12.24
# 17        1235 興泰  2017/03/31     7.24
# 18        1236 宏亞  2017/03/31    26.30
# 19   1256 鮮活果汁-KY  2017/03/31    17.72
# 20        1702 南僑  2017/03/31    12.51
# 21        1737 臺鹽  2017/03/31    17.24
# 22  910322 康師傅-DR  2017/03/31     0.00
# ...

# %%
# Out:
#              證券代碼         年月日  本益比-TSE
# 0         1201 味全  2017/03/31     0.00
# 1         1203 味王  2017/03/31    22.81
# 2         1210 大成  2017/03/31     9.57
# 3         1213 大飲  2017/03/31    66.30
# 4         1215 卜蜂  2017/03/31    11.51
# 5         1216 統一  2017/03/31    22.23
# 6        1217 愛之味  2017/03/31    35.90
# 7         1218 泰山  2017/03/31    15.85
# 8         1219 福壽  2017/03/31    33.88
# 9         1220 台榮  2017/03/31    11.99
# 10       1225 福懋油  2017/03/31    14.84
# 11        1227 佳格  2017/03/31    26.36
# 12        1229 聯華  2017/03/31    10.74
# 13       1231 聯華食  2017/03/31    11.32
# 14       1232 大統益  2017/03/31    16.34
# 15        1233 天仁  2017/03/31    20.03
# 16        1234 黑松  2017/03/31    12.24
# 17        1235 興泰  2017/03/31     7.24
# 18        1236 宏亞  2017/03/31    26.30
# 19   1256 鮮活果汁-KY  2017/03/31    17.72
# 20        1702 南僑  2017/03/31    12.51
# 21        1737 臺鹽  2017/03/31    17.24
# 22  910322 康師傅-DR  2017/03/31     0.00
# ...
